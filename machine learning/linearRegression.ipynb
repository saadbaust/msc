# %%
import pandas as pd 
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("houseprice.csv")

# %%
df.head(3)
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000

# %%
plt.xlabel("Area")
plt.ylabel("Price")

plt.scatter(df.Area,df.Price,color="red",marker="+")

# %%
x=df.drop("Price",axis="columns")

# %%
y=df.Price

# %%
model=linear_model.LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
Y=model.predict([[1000]])
Y
# Out:
# c:\Users\Saad Ahmed\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([316404.10958904])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
plt.xlabel("Area")
plt.ylabel("Price")

plt.scatter(df.Area,df.Price,color="red",marker="+")
plt.plot(x,model.predict(x))
